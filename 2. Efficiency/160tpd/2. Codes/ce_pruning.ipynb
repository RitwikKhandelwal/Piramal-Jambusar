# %%
import pandas as pd

# %%
df = pd.read_csv("ce_setout_final_R.csv")

# %%
df
# Out:
#               Date      Time                            Identifier LineName  \
# 0       2021-11-03  21:30:00  1849d915-26c2-4fb1-b4a2-000183958622      J16
# 1       2021-11-03  21:30:00  1849d915-26c2-4fb1-b4a2-000183958622      J16
# 2       2021-11-03  21:30:00  1849d915-26c2-4fb1-b4a2-000183958622      J16
# 3       2021-11-03  21:30:00  1849d915-26c2-4fb1-b4a2-000183958622      J16
# 4       2021-11-03  21:30:00  1849d915-26c2-4fb1-b4a2-000183958622      J16
# ...            ...       ...                                   ...      ...
# 107535  2021-01-31  03:30:00  47a0a8cb-9535-4109-aa43-402222b0c9ed      J17
# 107536  2021-06-04  03:30:00  b86b4fd3-1e54-4f8d-ad6f-40261e38d3e2      J18
# 107537  2021-06-04  03:30:00  b86b4fd3-1e54-4f8d-ad6f-40261e38d3e2      J18
# 107538  2021-06-04  03:30:00  b86b4fd3-1e54-4f8d-ad6f-40261e38d3e2      J18
# 107539  2021-06-04  03:30:00  b86b4fd3-1e54-4f8d-ad6f-40261e38d3e2      J18
#
# ...

# %%
df = df[df["LineName"] == "J13"]

# %%
df = df[df["Name"] == "Bubble (>2.5 mm)"]

# %%
df
# Out:
#               Date      Time                            Identifier LineName  \
# 177     2021-06-10  11:30:00  c09bce88-159c-4188-9d6f-001f73e9b8f1      J13
# 185     2021-06-10  11:30:00  c09bce88-159c-4188-9d6f-001f73e9b8f1      J13
# 186     2021-06-10  11:30:00  c09bce88-159c-4188-9d6f-001f73e9b8f1      J13
# 187     2021-06-10  11:30:00  c09bce88-159c-4188-9d6f-001f73e9b8f1      J13
# 188     2021-06-10  11:30:00  c09bce88-159c-4188-9d6f-001f73e9b8f1      J13
# ...            ...       ...                                   ...      ...
# 107445  2021-05-29  10:30:00  08977288-f440-46b2-840d-400eb7624c9a      J13
# 107446  2021-05-29  10:30:00  08977288-f440-46b2-840d-400eb7624c9a      J13
# 107447  2021-05-29  10:30:00  08977288-f440-46b2-840d-400eb7624c9a      J13
# 107448  2021-05-29  10:30:00  08977288-f440-46b2-840d-400eb7624c9a      J13
# 107461  2021-05-29  10:30:00  08977288-f440-46b2-840d-400eb7624c9a      J13
#
# ...

# %%
df2 = df['Name'].value_counts()

# %%
df.to_csv("CE_Setout_J13.csv")

# %%
df2 = df[]
